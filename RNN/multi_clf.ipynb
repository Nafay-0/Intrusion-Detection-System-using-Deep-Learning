# %%
import pandas as pd
import numpy as np

# %%
def load_dataset():
    train_df = pd.read_csv("../Data/UNSW_NB15_testing-set.csv")
    test_df = pd.read_csv("../Data/UNSW_NB15_training-set.csv")
    return train_df, test_df

# %%
def data_preprocessing_attack_cat(data):
    data["attack_cat"] = data["attack_cat"].fillna('Normal')
    data["attack_cat"] = data["attack_cat"].replace(' Fuzzers','Fuzzers')
    data["attack_cat"] = data["attack_cat"].replace(' Fuzzers ','Fuzzers')
    data["attack_cat"] = data["attack_cat"].replace(' Reconnaissance','Reconnaissance')
    data["attack_cat"] = data["attack_cat"].replace(' Reconnaissance ','Reconnaissance')
    data["attack_cat"] = data["attack_cat"].replace(' Shellcode','Shellcode')
    data["attack_cat"] = data["attack_cat"].replace(' Shellcode ','Shellcode')
    data["attack_cat"] = data["attack_cat"].replace('Backdoors','Backdoor')
    return data

# %%
def visualize_attack_cats(data):
    import seaborn as sns
    import matplotlib.pyplot as plt
    plt.figure(figsize=(20,10))
    sns.countplot(x="attack_cat", data=data)
    plt.show()

# %%
def preprocess_numerical_cols(df):
    numerical_cols = df.select_dtypes(exclude=["object"]).columns
    df[numerical_cols] = df[numerical_cols].fillna(0)
    return df

# %%
def preprocess_categorical_cols(df):
    categorical_cols = df.select_dtypes(include=["object"]).columns
    categorical_cols = list(categorical_cols)
    categorical_cols.remove("attack_cat")
    df[categorical_cols] = df[categorical_cols].replace('-', "None")
    df[categorical_cols] = df[categorical_cols].fillna("None")
    return df

# %%
def preprocess_data(df):
    df = preprocess_numerical_cols(df)
    df = preprocess_categorical_cols(df)
    return df

# %%
from sklearn.preprocessing import OneHotEncoder
def one_hot_encode_fit_col(data, col):
    values = data[col].unique()
    for index, v_col in enumerate(values):
        values[index] = col+"_"+v_col
        data[col+"_"+v_col] = np.zeros(len(data))
    enc = OneHotEncoder(handle_unknown='ignore')
    data[values] = enc.fit_transform(data[col].values.reshape(-1,1)).toarray()
    data = data.drop([col],axis=1)
    return data, enc, values

# %%
def one_hot_encode_transform_col(data, col, enc, col_values):
    for v_col in col_values:
        data[v_col] = np.zeros(len(data))
    data[col_values] = enc.transform(data[col].values.reshape(-1,1)).toarray()
    data = data.drop([col],axis=1)
    return data

# %%
def label_encoder_fit_col(data, col):
    values = ["out"]
    values.extend(data[col].unique())
    dict_values = {k: v for v, k in enumerate(values)}
    #print(dict_values)
    data[col] = data[col].apply(lambda x: dict_values[x])
    data[col] = data[col].astype("int32")
    return data, dict_values

# %%
def label_encoder_transform_col(data, col, dict_values):
    data[col] = data[col].apply(lambda x: dict_values[x] if x in dict_values else 0)
    data[col] = data[col].astype("int32")
    return data

# %%
from sklearn.utils import class_weight
def get_class_weights(y):
    class_weights = class_weight.compute_class_weight('balanced',
                                                     classes=np.unique(y),
                                                     y=y)
    class_weights = {k: v for k,v in enumerate(class_weights)}
    return class_weights

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
def label_encode(y,num_classes):
    cls_label_encoder = LabelEncoder()
    y = cls_label_encoder.fit_transform(y)
    y = to_categorical(y, num_classes=num_classes)
    return y, cls_label_encoder
# Out:
# WARNING:tensorflow:From c:\users\user\appdata\local\programs\python\python39\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
"""
This function is used to print the scores
"""
from sklearn.metrics import accuracy_score, precision_recall_fscore_support,confusion_matrix, classification_report, precision_score, recall_score, f1_score
def print_score(y_pred, y_real,cls_label_encoder):
    print("Accuracy: ", accuracy_score(y_real, y_pred))
    print ("Precision Score: ", precision_score(y_real, y_pred, average='weighted'))
    print ("Recall Score: ", recall_score(y_real, y_pred, average='weighted'))
    print ("F1 Score: ", f1_score(y_real, y_pred, average='weighted'))
    print("Confusion Matrix")
    print(confusion_matrix(y_real, y_pred))

# %%
import keras.backend as K

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
from sklearn.preprocessing import MinMaxScaler
def min_max_scaler_fit_col(data):
    scaler = MinMaxScaler(feature_range=(0,1))
    data = scaler.fit_transform(data)
    return data

# %%
train_df,test_df = load_dataset()

# %%
train_df = train_df.drop(["id"], axis=1)
test_df = test_df.drop(["id"], axis=1)

# %%
train_df = data_preprocessing_attack_cat(train_df)
test_df = data_preprocessing_attack_cat(test_df)

# %%
visualize_attack_cats(train_df)

# %%
train_df = preprocess_data(train_df)
test_df = preprocess_data(test_df)

# %%
train_df, dict_values = label_encoder_fit_col(train_df, "proto")
test_df = label_encoder_transform_col(test_df, "proto", dict_values)

# %%
train_df, dict_values = label_encoder_fit_col(train_df, "service")
test_df = label_encoder_transform_col(test_df, "service", dict_values)

# %%
train_df, dict_values = label_encoder_fit_col(train_df, "state")
test_df = label_encoder_transform_col(test_df, "state", dict_values)

# %%
train_df = train_df.sample(frac=1).reset_index(drop=True)

# %%
X_train = train_df.drop(["label", "attack_cat"], axis=1)
y_train = train_df["attack_cat"]
X_test = test_df.drop(["label", "attack_cat"], axis=1)
y_test = test_df["attack_cat"]

# %%
X_train = min_max_scaler_fit_col(X_train)
X_test = min_max_scaler_fit_col(X_test)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
class_weights = get_class_weights(y_train)

# %%
y_train, cls_label_encoder = label_encode(y_train, len(np.unique(y_train)))
y_test, _ = label_encode(y_test, len(np.unique(y_test)))

# %%
cls_label_encoder.classes_
# Out:
# array(['Analysis', 'Backdoor', 'DoS', 'Exploits', 'Fuzzers', 'Generic',
#        'Normal', 'Reconnaissance', 'Shellcode', 'Worms'], dtype=object)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (175341, 10)
# (82332, 10)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (175341, 42, 1)
# (82332, 42, 1)

# %%
from keras.layers import Dense, Dropout, BatchNormalization,SimpleRNN
from keras.models import Sequential
def create_RNN_model(input_shape,activation = 'leaky_relu',dropout_rate=0.2, num_classes=10):
    model = Sequential()
    model.add(SimpleRNN(256, input_shape=input_shape, activation=activation, return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(BatchNormalization())
    model.add(SimpleRNN(128, activation=activation))
    model.add(Dropout(dropout_rate))
    model.add(BatchNormalization())
    model.add(Dense(128, activation=activation))
    model.add(Dropout(dropout_rate))
    model.add(BatchNormalization())
    model.add(Dense(128, activation=activation))
    model.add(Dropout(dropout_rate))
    model.add(BatchNormalization())
    model.add(Dense(64, activation=activation))
    model.add(Dropout(dropout_rate))
    model.add(BatchNormalization())
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
input_shape = X_train.shape[1:]

# %%
from sklearn.model_selection import ParameterSampler
import tensorflow as tf
def tune_hyperparams():
    # use random serch to tune hyperparameters
    params_grid = {
        'batch_size': [32, 64, 128],
        'epochs': [10, 20, 30],
        'learning_rate': [0.0001, 0.001, 0.01],
        'dropout_rate': [0.2, 0.25, 0.3],
        'activation': ['relu', 'leaky_relu', 'tan_h'],
        'optimizer': ['adam', 'sgd', 'rmsprop']
    }
    params_list = list(ParameterSampler(params_grid, n_iter=10, random_state=42))
    best_params = None
    for params in params_list:
        print("Trying Out : ",params)
        model =  create_RNN_model(input_shape, activation=params['activation'], dropout_rate=params['dropout_rate'], num_classes=10)
        if params['optimizer'] == 'adam':
            optimizer = tf.keras.optimizers.Adam(learning_rate=params['learning_rate'])
        elif params['optimizer'] == 'sgd':
            optimizer = tf.keras.optimizers.SGD(learning_rate=params['learning_rate'])
        else:
            optimizer = tf.keras.optimizers.RMSprop(learning_rate=params['learning_rate'])
        model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
        model.fit(X_train, y_train, epochs=params['epochs'], batch_size=params['batch_size'], 
                  validation_split=0.2, class_weight=class_weights)
        _, accuracy = model.evaluate(X_test, y_test)
        if best_params is None or accuracy > best_params['accuracy']:
            best_params = {'accuracy': accuracy, 'params': params}
    print("Best Params : ", best_params)

# %%
# tune_hyperparams()

# %%
rnn_clf = create_RNN_model(input_shape, activation='relu', dropout_rate=0.2, num_classes=10)

# %%
from tensorflow.keras.metrics import Recall, Precision
import tensorflow.keras as keras
rnn_clf.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss='binary_crossentropy', 
                 metrics=['accuracy', Precision(), Recall(), f1_score])

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

model_weights_file_path = "rnn_mul_clf.h5"
checkpoint = ModelCheckpoint(filepath=model_weights_file_path, monitor="val_accuracy",
                             verbose=1, save_best_only=True, mode="max", save_weights_only=True)
early_stopping = EarlyStopping(monitor="val_accuracy", mode="max", verbose=1, patience=20)
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, 
                              verbose=1, mode='max', min_delta=0.0001, cooldown=0)

call_backs = [checkpoint, early_stopping, lr_reduce]

# %%
rnn_clf.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 42, 256)           66048
#
#  dropout_4 (Dropout)         (None, 42, 256)           0
#
#  batch_normalization_4 (Bat  (None, 42, 256)           1024
#  chNormalization)
#
#  simple_rnn_1 (SimpleRNN)    (None, 128)               49280
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  batch_normalization_5 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  batch_normalization_6 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  batch_normalization_7 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 160074 (625.29 KB)
# Trainable params: 158666 (619.79 KB)
# Non-trainable params: 1408 (5.50 KB)
# _________________________________________________________________

# %%
EPOCHS = 30
BATCH_SIZE = 256
history_clf = rnn_clf.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, 
             validation_split=0.2, class_weight=class_weights, callbacks=call_backs)
# Out:
# Epoch 1/30
# 548/548 [==============================] - ETA: 0s - loss: 0.2249 - accuracy: 0.5511 - precision_2: 0.9476 - recall_2: 0.4504 - f1_score: 0.6101
# Epoch 1: val_accuracy improved from 0.48271 to 0.50649, saving model to rnn_mul_clf.h5
# 548/548 [==============================] - 65s 118ms/step - loss: 0.2249 - accuracy: 0.5511 - precision_2: 0.9476 - recall_2: 0.4504 - f1_score: 0.6101 - val_loss: 0.1829 - val_accuracy: 0.5065 - val_precision_2: 0.9987 - val_recall_2: 0.4224 - val_f1_score: 0.5911 - lr: 0.0010
# Epoch 2/30
# 548/548 [==============================] - ETA: 0s - loss: 0.2099 - accuracy: 0.5977 - precision_2: 0.8708 - recall_2: 0.4746 - f1_score: 0.6137
# Epoch 2: val_accuracy did not improve from 0.50649
# 548/548 [==============================] - 64s 117ms/step - loss: 0.2099 - accuracy: 0.5977 - precision_2: 0.8708 - recall_2: 0.4746 - f1_score: 0.6137 - val_loss: 0.2759 - val_accuracy: 0.3278 - val_precision_2: 0.6091 - val_recall_2: 0.2828 - val_f1_score: 0.3846 - lr: 0.0010
# Epoch 3/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1951 - accuracy: 0.6363 - precision_2: 0.8259 - recall_2: 0.5459 - f1_score: 0.6569
# Epoch 3: val_accuracy improved from 0.50649 to 0.62540, saving model to rnn_mul_clf.h5
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1951 - accuracy: 0.6363 - precision_2: 0.8259 - recall_2: 0.5459 - f1_score: 0.6569 - val_loss: 0.1627 - val_accuracy: 0.6254 - val_precision_2: 0.7609 - val_recall_2: 0.5493 - val_f1_score: 0.6370 - lr: 0.0010
# Epoch 4/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.6467 - precision_2: 0.8192 - recall_2: 0.5751 - f1_score: 0.6755
# Epoch 4: val_accuracy improved from 0.62540 to 0.64302, saving model to rnn_mul_clf.h5
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1900 - accuracy: 0.6467 - precision_2: 0.8192 - recall_2: 0.5751 - f1_score: 0.6755 - val_loss: 0.1604 - val_accuracy: 0.6430 - val_precision_2: 0.7624 - val_recall_2: 0.5517 - val_f1_score: 0.6392 - lr: 0.0010
# Epoch 5/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1838 - accuracy: 0.6546 - precision_2: 0.8171 - recall_2: 0.5914 - f1_score: 0.6858
# Epoch 5: val_accuracy improved from 0.64302 to 0.64998, saving model to rnn_mul_clf.h5
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1838 - accuracy: 0.6546 - precision_2: 0.8171 - recall_2: 0.5914 - f1_score: 0.6858 - val_loss: 0.1310 - val_accuracy: 0.6500 - val_precision_2: 0.7979 - val_recall_2: 0.6281 - val_f1_score: 0.7020 - lr: 0.0010
# Epoch 6/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.6714 - precision_2: 0.8247 - recall_2: 0.6132 - f1_score: 0.7032
# Epoch 6: val_accuracy improved from 0.64998 to 0.68465, saving model to rnn_mul_clf.h5
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1778 - accuracy: 0.6714 - precision_2: 0.8247 - recall_2: 0.6132 - f1_score: 0.7032 - val_loss: 0.1276 - val_accuracy: 0.6847 - val_precision_2: 0.8348 - val_recall_2: 0.6268 - val_f1_score: 0.7150 - lr: 0.0010
# Epoch 7/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.6759 - precision_2: 0.8286 - recall_2: 0.6202 - f1_score: 0.7092
# Epoch 7: val_accuracy improved from 0.68465 to 0.70384, saving model to rnn_mul_clf.h5
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1759 - accuracy: 0.6759 - precision_2: 0.8286 - recall_2: 0.6202 - f1_score: 0.7092 - val_loss: 0.1296 - val_accuracy: 0.7038 - val_precision_2: 0.8273 - val_recall_2: 0.6474 - val_f1_score: 0.7254 - lr: 0.0010
# Epoch 8/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.6821 - precision_2: 0.8351 - recall_2: 0.6307 - f1_score: 0.7184
# Epoch 8: val_accuracy did not improve from 0.70384
# 548/548 [==============================] - 64s 116ms/step - loss: 0.1722 - accuracy: 0.6821 - precision_2: 0.8351 - recall_2: 0.6307 - f1_score: 0.7184 - val_loss: 0.1461 - val_accuracy: 0.6243 - val_precision_2: 0.7610 - val_recall_2: 0.6068 - val_f1_score: 0.6744 - lr: 0.0010
# Epoch 9/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.6886 - precision_2: 0.8386 - recall_2: 0.6392 - f1_score: 0.7253
# Epoch 9: val_accuracy did not improve from 0.70384
# 548/548 [==============================] - 64s 116ms/step - loss: 0.1685 - accuracy: 0.6886 - precision_2: 0.8386 - recall_2: 0.6392 - f1_score: 0.7253 - val_loss: 0.1360 - val_accuracy: 0.7031 - val_precision_2: 0.8254 - val_recall_2: 0.6367 - val_f1_score: 0.7179 - lr: 0.0010
# Epoch 10/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.6768 - precision_2: 0.8356 - recall_2: 0.6229 - f1_score: 0.7134
# Epoch 10: val_accuracy did not improve from 0.70384
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1755 - accuracy: 0.6768 - precision_2: 0.8356 - recall_2: 0.6229 - f1_score: 0.7134 - val_loss: 0.2615 - val_accuracy: 0.4568 - val_precision_2: 0.5013 - val_recall_2: 0.4451 - val_f1_score: 0.4712 - lr: 0.0010
# Epoch 11/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.6916 - precision_2: 0.8428 - recall_2: 0.6439 - f1_score: 0.7299
# Epoch 11: val_accuracy did not improve from 0.70384
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1654 - accuracy: 0.6916 - precision_2: 0.8428 - recall_2: 0.6439 - f1_score: 0.7299 - val_loss: 0.1279 - val_accuracy: 0.6732 - val_precision_2: 0.8333 - val_recall_2: 0.6466 - val_f1_score: 0.7272 - lr: 0.0010
# Epoch 12/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.6938 - precision_2: 0.8452 - recall_2: 0.6500 - f1_score: 0.7346
# Epoch 12: val_accuracy improved from 0.70384 to 0.74542, saving model to rnn_mul_clf.h5
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1623 - accuracy: 0.6938 - precision_2: 0.8452 - recall_2: 0.6500 - f1_score: 0.7346 - val_loss: 0.1151 - val_accuracy: 0.7454 - val_precision_2: 0.8627 - val_recall_2: 0.6766 - val_f1_score: 0.7574 - lr: 0.0010
# Epoch 13/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.6962 - precision_2: 0.8455 - recall_2: 0.6512 - f1_score: 0.7355
# Epoch 13: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 66s 121ms/step - loss: 0.1605 - accuracy: 0.6962 - precision_2: 0.8455 - recall_2: 0.6512 - f1_score: 0.7355 - val_loss: 0.1541 - val_accuracy: 0.6341 - val_precision_2: 0.7629 - val_recall_2: 0.6088 - val_f1_score: 0.6765 - lr: 0.0010
# Epoch 14/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1597 - accuracy: 0.7009 - precision_2: 0.8453 - recall_2: 0.6523 - f1_score: 0.7362
# Epoch 14: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1597 - accuracy: 0.7009 - precision_2: 0.8453 - recall_2: 0.6523 - f1_score: 0.7362 - val_loss: 0.1252 - val_accuracy: 0.6860 - val_precision_2: 0.8369 - val_recall_2: 0.6669 - val_f1_score: 0.7414 - lr: 0.0010
# Epoch 15/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.6966 - precision_2: 0.8458 - recall_2: 0.6537 - f1_score: 0.7372
# Epoch 15: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1592 - accuracy: 0.6966 - precision_2: 0.8458 - recall_2: 0.6537 - f1_score: 0.7372 - val_loss: 0.1153 - val_accuracy: 0.6903 - val_precision_2: 0.8499 - val_recall_2: 0.6671 - val_f1_score: 0.7465 - lr: 0.0010
# Epoch 16/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1609 - accuracy: 0.6917 - precision_2: 0.8400 - recall_2: 0.6487 - f1_score: 0.7318
# Epoch 16: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 65s 119ms/step - loss: 0.1609 - accuracy: 0.6917 - precision_2: 0.8400 - recall_2: 0.6487 - f1_score: 0.7318 - val_loss: 0.1156 - val_accuracy: 0.7377 - val_precision_2: 0.8448 - val_recall_2: 0.6826 - val_f1_score: 0.7542 - lr: 0.0010
# Epoch 17/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1565 - accuracy: 0.7000 - precision_2: 0.8453 - recall_2: 0.6592 - f1_score: 0.7405
# Epoch 17: val_accuracy did not improve from 0.74542
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1565 - accuracy: 0.7000 - precision_2: 0.8453 - recall_2: 0.6592 - f1_score: 0.7405 - val_loss: 0.1138 - val_accuracy: 0.7245 - val_precision_2: 0.8591 - val_recall_2: 0.6823 - val_f1_score: 0.7596 - lr: 0.0010
# Epoch 18/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.7051 - precision_2: 0.8514 - recall_2: 0.6653 - f1_score: 0.7467
# Epoch 18: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 65s 119ms/step - loss: 0.1528 - accuracy: 0.7051 - precision_2: 0.8514 - recall_2: 0.6653 - f1_score: 0.7467 - val_loss: 0.1133 - val_accuracy: 0.7040 - val_precision_2: 0.8553 - val_recall_2: 0.6852 - val_f1_score: 0.7600 - lr: 5.0000e-04
# Epoch 19/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1499 - accuracy: 0.7071 - precision_2: 0.8516 - recall_2: 0.6688 - f1_score: 0.7491
# Epoch 19: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1499 - accuracy: 0.7071 - precision_2: 0.8516 - recall_2: 0.6688 - f1_score: 0.7491 - val_loss: 0.1171 - val_accuracy: 0.6990 - val_precision_2: 0.8452 - val_recall_2: 0.6803 - val_f1_score: 0.7530 - lr: 5.0000e-04
# Epoch 20/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.7105 - precision_2: 0.8520 - recall_2: 0.6695 - f1_score: 0.7496
# Epoch 20: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1494 - accuracy: 0.7105 - precision_2: 0.8520 - recall_2: 0.6695 - f1_score: 0.7496 - val_loss: 0.1151 - val_accuracy: 0.6971 - val_precision_2: 0.8462 - val_recall_2: 0.6770 - val_f1_score: 0.7513 - lr: 5.0000e-04
# Epoch 21/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.7103 - precision_2: 0.8556 - recall_2: 0.6732 - f1_score: 0.7533
# Epoch 21: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1476 - accuracy: 0.7103 - precision_2: 0.8556 - recall_2: 0.6732 - f1_score: 0.7533 - val_loss: 0.1173 - val_accuracy: 0.6973 - val_precision_2: 0.8479 - val_recall_2: 0.6761 - val_f1_score: 0.7514 - lr: 5.0000e-04
# Epoch 22/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.7108 - precision_2: 0.8556 - recall_2: 0.6743 - f1_score: 0.7540
# Epoch 22: val_accuracy did not improve from 0.74542
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 548/548 [==============================] - 64s 118ms/step - loss: 0.1448 - accuracy: 0.7108 - precision_2: 0.8556 - recall_2: 0.6743 - f1_score: 0.7540 - val_loss: 0.1129 - val_accuracy: 0.7105 - val_precision_2: 0.8486 - val_recall_2: 0.6837 - val_f1_score: 0.7564 - lr: 5.0000e-04
# Epoch 23/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 0.7120 - precision_2: 0.8567 - recall_2: 0.6766 - f1_score: 0.7559
# Epoch 23: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 67s 121ms/step - loss: 0.1433 - accuracy: 0.7120 - precision_2: 0.8567 - recall_2: 0.6766 - f1_score: 0.7559 - val_loss: 0.1183 - val_accuracy: 0.7070 - val_precision_2: 0.8483 - val_recall_2: 0.6764 - val_f1_score: 0.7517 - lr: 2.5000e-04
# Epoch 24/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.7124 - precision_2: 0.8566 - recall_2: 0.6756 - f1_score: 0.7552
# Epoch 24: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1434 - accuracy: 0.7124 - precision_2: 0.8566 - recall_2: 0.6756 - f1_score: 0.7552 - val_loss: 0.1127 - val_accuracy: 0.7080 - val_precision_2: 0.8520 - val_recall_2: 0.6857 - val_f1_score: 0.7590 - lr: 2.5000e-04
# Epoch 25/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.7117 - precision_2: 0.8593 - recall_2: 0.6767 - f1_score: 0.7569
# Epoch 25: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1416 - accuracy: 0.7117 - precision_2: 0.8593 - recall_2: 0.6767 - f1_score: 0.7569 - val_loss: 0.1128 - val_accuracy: 0.7030 - val_precision_2: 0.8530 - val_recall_2: 0.6845 - val_f1_score: 0.7586 - lr: 2.5000e-04
# Epoch 26/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.7125 - precision_2: 0.8586 - recall_2: 0.6767 - f1_score: 0.7567
# Epoch 26: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 66s 120ms/step - loss: 0.1411 - accuracy: 0.7125 - precision_2: 0.8586 - recall_2: 0.6767 - f1_score: 0.7567 - val_loss: 0.1122 - val_accuracy: 0.7039 - val_precision_2: 0.8532 - val_recall_2: 0.6848 - val_f1_score: 0.7589 - lr: 2.5000e-04
# Epoch 27/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.7086 - precision_2: 0.8579 - recall_2: 0.6767 - f1_score: 0.7564
# Epoch 27: val_accuracy did not improve from 0.74542
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 548/548 [==============================] - 64s 117ms/step - loss: 0.1416 - accuracy: 0.7086 - precision_2: 0.8579 - recall_2: 0.6767 - f1_score: 0.7564 - val_loss: 0.1127 - val_accuracy: 0.7217 - val_precision_2: 0.8501 - val_recall_2: 0.6852 - val_f1_score: 0.7579 - lr: 2.5000e-04
# Epoch 28/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.7177 - precision_2: 0.8587 - recall_2: 0.6785 - f1_score: 0.7578
# Epoch 28: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 67s 122ms/step - loss: 0.1396 - accuracy: 0.7177 - precision_2: 0.8587 - recall_2: 0.6785 - f1_score: 0.7578 - val_loss: 0.1126 - val_accuracy: 0.7057 - val_precision_2: 0.8564 - val_recall_2: 0.6874 - val_f1_score: 0.7618 - lr: 1.2500e-04
# Epoch 29/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.7137 - precision_2: 0.8598 - recall_2: 0.6793 - f1_score: 0.7588
# Epoch 29: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 66s 121ms/step - loss: 0.1386 - accuracy: 0.7137 - precision_2: 0.8598 - recall_2: 0.6793 - f1_score: 0.7588 - val_loss: 0.1125 - val_accuracy: 0.7081 - val_precision_2: 0.8542 - val_recall_2: 0.6852 - val_f1_score: 0.7595 - lr: 1.2500e-04
# Epoch 30/30
# 548/548 [==============================] - ETA: 0s - loss: 0.1380 - accuracy: 0.7158 - precision_2: 0.8606 - recall_2: 0.6794 - f1_score: 0.7591
# Epoch 30: val_accuracy did not improve from 0.74542
# 548/548 [==============================] - 65s 118ms/step - loss: 0.1380 - accuracy: 0.7158 - precision_2: 0.8606 - recall_2: 0.6794 - f1_score: 0.7591 - val_loss: 0.1126 - val_accuracy: 0.7048 - val_precision_2: 0.8546 - val_recall_2: 0.6876 - val_f1_score: 0.7612 - lr: 1.2500e-04

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support,confusion_matrix, classification_report
def evaluate_Test(model, X_test, y_test, cls_label_encoder):
    y_hat = model.predict(X_test)
    y_hat = np.argmax(y_hat, axis=1)
    y_true = np.argmax(y_test, axis=1)
    print_score(y_hat, y_true, cls_label_encoder)

# %%
def visualize_loss(history):
    import matplotlib.pyplot as plt
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend(['train', 'val'], loc='upper right')
    plt.show()

# %%
def visualize_accuracy(history):
    import matplotlib.pyplot as plt
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Loss')
    plt.xlabel('Epochs')
    plt.legend(['train', 'val'], loc='upper right')
    plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support,confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
def plot_confusion_matrix(model, X_test, y_test):
    y_hat = model.predict(X_test)
    y_hat = np.argmax(y_hat, axis=1)
    y_true = np.argmax(y_test, axis=1)
    cm = confusion_matrix(y_true, y_hat)
    plt.figure(figsize=(20,10))
    sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=cls_label_encoder.classes_, yticklabels=cls_label_encoder.classes_)
    plt.show()

# %%
evaluate_Test(rnn_clf, X_test, y_test, cls_label_encoder)
# Out:
# 2573/2573 [==============================] - 33s 13ms/step
# Accuracy:  0.6106617111208279
# Precision Score:  0.775620346870699
# Recall Score:  0.6106617111208279
# F1 Score:  0.6577447501111823
# Confusion Matrix
# [[   14   532     0    47    43    38     3     0     0     0]
#  [   12   454     5    10    48    38     0    10     0     6]
#  [  191  2610   129   617   147   148     7   122     1   117]
#  [  304  2901   327  5711   312   190    21   494    10   862]
#  [   40  1196   192   456  2488   646   148   652    30   214]
#  [    4    97    51   359    30 18090     2   182     2    54]
#  [ 2161   419   185   609  8045  2774 21310  1087    28   382]
#  [   15  1110     0     9   114    19     0  2044     0   185]
#  [    0   183     3    11    28     6     0   108     3    36]
#  [    0     4     2     1     1     0     0     2     0    34]]

# %%
visualize_loss(history_clf)

# %%
visualize_accuracy(history_clf)

# %%
plot_confusion_matrix(rnn_clf, X_test, y_test)
# Out:
# 2573/2573 [==============================] - 26s 10ms/step
